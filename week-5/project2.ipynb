# %%
import tkinter as tk
from tkinter import messagebox as msgbox














root = tk.Tk()
root.title("L'ORIENT DELIVERY SERVICES🚚")
root.geometry('500x500')

tk.Label(root, text="L'ORIENT DELIVERY",font=('monotype corsiva',20), fg='navy').pack(pady=0)
tk.Label(root, text = 'SERVICES',font=('monotype corsiva',30),fg= 'Navy').pack(pady=0)
tk.Label(root, text = '🚚',font=('monotype corsiva',20),fg= 'Navy').pack(pady=0)

tk.Label(root, text = 'Enter your Location',font=(15),fg= 'navy').pack(pady=0)
location = tk.Entry(root, width = 20)
location.pack(pady=5)

tk.Label(root, text = 'Enter the weight of the package',font= (15),fg= 'navy').pack(pady=0)
weight = tk.Entry(root, width = 7)
weight.pack(pady=5)

tk.Button(root, text = 'Submit',bg ='black',fg = 'white').pack(pady=5)

root.mainloop()
