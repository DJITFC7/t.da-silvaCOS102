# %%
a = float,input("Input the coefficient of x")
b = float,input("Input the coefficient of y") 
c = float,input("Input the last number ")
x1 = ( (b * -1) - ((b**2 -4*a*c)//2)))/(2*a) 
x2 = ( (-b + ((b**2 -4*a*c)//2)))/(2*a) 
print (f"Roots are {x1} and {x2} ")
# Out:
# Input the coefficient of x 3
# Input the coefficient of y 4
# Input the last number  5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 b = float,input("Input the coefficient of y")
#       3 c = float,input("Input the last number ")
# ----> 4 x1 = ( (-b - ((b**2 -4*a*c)//2)))/(2*a)
#       5 x2 = ( (-b + ((b**2 -4*a*c)//2)))/(2*a)
#       6 print (f"Roots are {x1} and {x2} ")
#
# TypeError: bad operand type for unary -: 'tuple'
