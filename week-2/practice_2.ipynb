# %%
city_1 = input('Enter city 1')
city_2 = input('Enter city 2')

temp = city_1
city_1 = city_2
city_2 = temp

print(f"The name of city 1 now is {city_1}")
print(f"The name of city 2 now is {city_2}")
# Out:
# Enter city 1 london
# Enter city 2 lagos
# The name of city 1 now is lagos
# The name of city 2 now is london

# %%
num = float(input("Enter a number"))
if num > 0:
    print ('positive number')
elif num == 0:
    print('0')    
else:
    print('Negative number')
# Out:
# Enter a number 4
# positive number

# %%
print("WELCOME TO COUUPE DE ESCRIVA 2023: FOOTBall picks \n")

Captain ={'Madiba: ': 'Chubby Obiora-Okafor', 'BLue-Jays: ': 'Christopher UWeh','Cirok: ':'Alexander', 'TSG Walkers: ':'Ikechukwu'}
goalkeepers ={'Madiba':'Chubby Obiora OKafor','Blue-Jays: ': 'Oladimeji /Jeffery','Cirok: ': 'Timileyin Pearse/Izuako Jeremy','TSG Walkers:':'Ayomide Ojituku'}

for pick in Captain:
    print(pick, Captain[pick])

print("\n")

 for pick in goalkeepers:
    print(pick, goalkeepers[pick])
# Out:
#   Cell In[16], line 11
#     for pick in goalkeepers:
#     ^
# IndentationError: unexpected indent
