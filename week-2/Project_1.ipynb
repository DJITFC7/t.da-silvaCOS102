# %%
BEGIN
INPUT Items and price
COMPUTE Total cost of items
PRINT Total cost of items
END

# %% [markdown]
# ![image.png](attachment:bfbd9372-c3b7-4967-b287-f6f5bc41ca11.png)

# %% [markdown]
# ![image.png](attachment:f8c7076a-e749-4cf9-9bd4-4a34a1811460.png)

# %% [markdown]
# ![Screenshot 2026-03-11 152105.png](attachment:60b46b1a-1d29-4847-8956-143b2a99bf4d.png)
