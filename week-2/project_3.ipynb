# %%
import pandas as pd
print('GIRLS TABLE')
pname = ["Evelyn","Jessica","Somto","Edith","Liza","Madonna","Waje","Tola","Aisha","Latifa"]
page = [17,16,17,18,16,18,17,20,19,17]
pheight = [5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5]
pscores = [80,57,70,60,76,66,87,95,50,49]
ptable = pd.DataFrame({'name': pname, 'age': page, 'height': pheight, 'scores': pscores})
print(ptable)
# Out:
# GIRLS TABLE
#       name  age  height  scores
# 0   Evelyn   17     5.5      80
# 1  Jessica   16     6.0      57
# 2    Somto   17     5.4      70
# 3    Edith   18     5.9      60
# 4     Liza   16     5.6      76
# 5  Madonna   18     5.5      66
# 6     Waje   17     6.1      87
# 7     Tola   20     6.0      95
# 8    Aisha   19     5.7      50
# 9   Latifa   17     5.5      49

# %%
import pandas as pd
print('BOYS TABLE')

iname = ['Chinedu','Liam','Wale','Gbenga','Abiola','Kola','Kunle','George','Thomas','Wesley']
iage = [19,16,18,17,20,19,16,18,7,19]
iheight = [5.7,5.9,5.8,6.2,6.3,5.10,5.5,6.4,6.3,5.7]
iscores = [74,87,75,68,66,78,87,98,54,60]

itable = pd.DataFrame({'name': iname, 'age': iage,'height': iheight, 'scores': iscore)
