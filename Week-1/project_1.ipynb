# %% [markdown]
# ![Screenshot 2026-03-08 175402.png](attachment:2ba2ccaa-00d6-40ac-af7b-5382a06fa8e4.png)

# %%
 p= float(input("Enter Num: "))
 r=float(input("Enter Num: "))
 t= float(input("Enter Num: "))         
 A= p*(1+(r/100)*t)
 print ("Amount is: ", a )

# %%
p= float(input("Enter principle"))
r= float(input("Enter rate"))
n= float(input("Enter num"))
t= float(input("Enter num"))
a= p*(1+(r/n)**(n*t))
print ("CI is: ", a)

# %%
print("calculate annuity plan")
p= float(input("Enter principle"))
r= float(input("Enter rate"))
n= float(input("Enter num"))
t= float(input("Enter num"))
m= float(input("Enter num"))
a= p*m*t*(((1+r/n)**(n*t)-1)/(r/n))
print ("Annuity plan is: ", a)
# Out:
# calculate annuity plan
# Enter principle 4
# Enter rate 5
# Enter num 6
# Enter num 2
# Enter num 7
# Annuity plan is:  96820.01900564494
